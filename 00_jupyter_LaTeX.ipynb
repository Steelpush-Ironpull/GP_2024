# %%
from IPython.display import display, clear_output, HTML
import time

def countdown_timer(minutes):
    total_seconds = minutes * 60
    for seconds in range(total_seconds, 0, -1):
        mins, secs = divmod(seconds, 60)
        time_str = f"{mins:02}'{secs:02}''"
        clear_output(wait=True)
        # HTML with styling
        display(HTML(f'<div style="font-size: 24px; color: blue; font-weight: bold;">Time remaining: {time_str}</div>'))
        time.sleep(1)
    clear_output(wait=True)
    # Final message with different styling
    display(HTML('<div style="font-size: 24px; color: green; font-weight: bold;">Time\'s up!</div>'))

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSlquQbehFaMuUwUN32KhAS4AxK7WTUtKuZBQ&s" alt="The Jupyter logo">
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;">
# A notebook is a shareable document that combines:
#
# - computer code,
# - plain text,
# - data,
# - rich visualizations like:
#     - 3D models,
#     - charts,
#     - graphs,
#     - figures,
# - and interactive controls.
#
# A notebook, along with an editor, provides a fast <strong>interactive</strong> environment for prototyping and explaining code, exploring and visualizing data, and sharing ideas with others.
#
# Jupyter Notebook can (and should) become your <em>lab journal</em>, where you collect, document, analyze, and plot your data.
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.4; color: grey;">
# Ein Notebook ist ein gemeinsam nutzbares Dokument, das folgendes kombiniert:
#
# - Computercode,
# - Klartext,
# - Daten,
# - reichhaltige Visualisierungen wie:
#     - 3D-Modelle,
#     - Schaubilder,
#     - Diagramme,
#     - Figuren,
# - und interaktive Steuerelemente.
#
# Ein Notebook bietet zusammen mit einem Editor eine schnelle <strong>interaktive</strong> Umgebung für das Prototyping und die Dokumentation von Code, die Untersuchung und Visualisierung von Daten und den Austausch von Ideen mit anderen.
#
# Jupyter Notebook kann (und sollte) Ihr <em>Laborjournal</em> werden, in dem Sie Ihre Daten sammeln, dokumentieren, analysieren und darstellen.
# </div>
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5; margin-right: 20px;">
#
# A notebook is comprised of cells.
# There are three types of input cells where you can write the content for your
# notebook:
#
# - **Code cells**: The default type of cell, this type of cell consists of executable code.
# As far as this notebook is concerned, the code you write here will be Python, but
# Jupyter does provide an option for executing code written in other languages.
#
# - **Markdown cells**: This type of cell allows for a rich form of documentation for
# your code (see below). When executed, the input to a markdown cell is converted
# into HTML, which can include mathematical equations, font effects, lists, tables,
# embedded images and videos.
#
# - **Raw cells**: Input into this type of cell is not changed by the notebook: its content
# and formatting is preserved exactly.
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3; color: grey;">
#
# Ein Notebook setzt sich aus Zellen zusammen.
# Es gibt drei Arten von Eingabezellen, in die Sie den Inhalt Ihres Notebooks schreiben können:
#
# - **Code Zellen**: Dieser Zellentyp ist der Standardtyp und besteht aus ausführbarem Code.
# Soweit es dieses Notebook betrifft, ist der Code, den Sie hier schreiben, Python, aber Jupyter bietet Optionen zur Ausführung von Code, der in anderen Sprachen geschrieben wurde.
#
# - **Markdown Zellen**: Diese Art von Zellen ermöglicht eine umfangreiche Dokumentation für
# Ihren Code (siehe unten). Bei der Ausführung wird die Eingabe in eine Markdown-Zelle in HTML umgewandelt, das mathematische Gleichungen, Schrifteffekte, Listen, Tabellen und eingebettete Bilder und Videos enthalten kann.
#
# - **Raw Zellen**: Eingaben in diesen Zellentyp werden vom Notebook nicht verändert: ihr Inhalt
# und die Formatierung werden exakt beibehalten.
# </div>
# </div>

# %% [markdown]
# <div style="text-align: center;">
# <img src="./figures/cell_types.png" width="390">
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;">
# Each cell can consist of more than one line of input, and the cell is not interpreted
# until you “run” (i.e., execute) it.
#
# This is achieved by selecting the appropriate option from the menu bar (under the `Run` drop-down submenu); by clicking the “play” button on the toolbar; or through the following keyboard shortcuts:
#
# - **Shift+Enter**: Execute the cell, showing any output, and then move the cursor
# onto the cell below. If there is no cell below, a new, empty one will be created.
#
# - **Ctrl+Enter**: Execute the cell in place, but keep the cursor in the current cell.
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3; color: grey;">
# Jede Zelle kann aus mehreren Eingabezeilen bestehen und die Zelle wird erst interpretiert wenn Sie sie ausführen.
#
# Dies geschieht durch Auswahl der entsprechenden Option in der Menüleiste (unter dem Dropdown-Untermenü `Run`), durch Klicken auf die Schaltfläche "Play" in der Symbolleiste oder durch die folgenden Tastenkombinationen:
#
# - **Shift+Enter**: Führt die Zelle aus, wobei alle Ausgaben angezeigt werden, und bewegt dann den Cursor
# auf die Zelle darunter. Wenn sich darunter keine Zelle befindet, wird eine neue, leere Zelle erstellt.
#
# - **Strg+Enter**: Führt die Zelle an Ort und Stelle aus, lässt aber den Cursor in der aktuellen Zelle.
# </div>
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;">
#
# You can insert cells below (above) the current by clicking outside of the cell, or pressing `Esc` to exit the edit mode, and then pressing `B` (`A`).
#
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3; color: grey;">
#
# Sie können Zellen unterhalb (oberhalb) der aktuellen Zelle einfügen, indem Sie außerhalb der Zelle klicken oder `Esc` drücken, um den Bearbeitungsmodus zu verlassen, und dann `B` (`A`) drücken.
#
# </div>
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;">
#
# The following cell type is `raw` to show how to create chapter/section/subsection headlines by using a variable number of `#` before your text:
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3; color: grey;">
#
# Der folgende Zellentyp ist `raw`, um zu zeigen, wie man Kapitel-, Abschnitts- und Unterabschnittsüberschriften erstellt, indem man eine variable Anzahl von `#` vor dem Text verwendet:
# </div>
# </div>

# %% [raw]
# # Chapter
# ## Section
# ### Subsection
# #### Subsubsection
#
# - a list item
#     - a sublist item
#         - and so on
#
# **some bold text**
#
# _some italic text_

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.3;">
# When you write the same commands in Markdown mode, you get:
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3; color: grey;">
# Wenn Sie dieselben Befehle im Markdown-Modus schreiben, erhalten Sie:
# </div>
# </div>

# %% [markdown]
# # Chapter
# ## Section
# ### Subsection
# #### Subsubsection
#
# - a list item
#     - a sublist item
#         - and so on
#
# **some bold text**
#
# _some italic text_

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;">
#
# In the menu, click `View` and then `Table of Contents`: the outline tab on the left of your workspace reflects the order and hierarchy of your headlines.
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3; color: grey;">
#
# Klicken Sie im Menü auf `View` und dann auf `Table of Contents`: die Reihenfolge und Hierarchie Ihrer Überschriften kann auf der linken Seite des Arbeitsbereichs (Listen-Tab) wiedergegeben werden.
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.3;">
#
# ### Disclaimer
# The cells containing texts in both English and German side by side are a slightly more complex type of Markdown cells, as they are formatted using HTML syntax. While you're welcome to explore them, you are not required to learn HTML commands.
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3; color: grey;">
#
# ### Disclaimer
# Die Zellen, die Texte in Englisch und Deutsch nebeneinander enthalten, sind eine etwas komplexere Art von Markdown-Zellen, da sie mit HTML-Syntax formatiert sind. Sie können sie gerne erkunden, müssen aber keine HTML-Befehle lernen.
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.3;">
#
# # Jupyter's functionalities
# </div>
# <div style="width: 48%; line-height: 1.3;color: grey;">
#
# # Die Funktionen von Jupyter
# </div>
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.3;">
#
# ## Documentation (today)
#
# Markdown can also display mathematical equations using $\LaTeX$ syntax:
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3;color: grey;">
#
# ## Dokumentation (heute)
#
# Markdown kann auch mathematische Gleichungen in $\LaTeX$-Syntax darstellen:
# </div>
# </div>
# <div style="text-align: center; margin-top: 20px;">
#
# $$ \Delta U = \left( \dfrac{\partial U}{\partial T} \right)_V \Delta T + \left( \dfrac{\partial U}{\partial V} \right)_T \Delta V $$
# $$ F\left[ \Phi,\nabla \Phi \right] = \int_V f \left[\Phi,\nabla \Phi \right] ~dV $$
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.3;">
#
# ## Running Python (1st part of the course)
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3;color: grey;">
#
# ## Python ausführen (1. Teil des Kurses)
# </div>
# </div>

# %%
print("Hello, World")

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.3;">
#
# ## Importing and displaying data (2nd part of the course)
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3;color: grey;">
#
# ## Importieren und Anzeigen von Daten (2. Teil des Kurses)
# </div>
# </div>

# %%
import seaborn as sns
penguins = sns.load_dataset("penguins")
penguins

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.3;">
#
# ## Plotting data (3rd part of the course)
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3;color: grey;">
#
# ## Plotten von Daten (3. Teil des Kurses)
# </div>
# </div>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the penguins dataset from a local file
#penguins = pd.read_csv('penguins.csv')

import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme()
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-light">
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.3;">
#
# ## Exercises
# </div>
# <div style="width: 48%; line-height: 1.3;color: grey;">
#
# ## Übungen
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-light">
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.3;">
#
# ### 1
#  Explore the Jupyter interface:
#
# - Open a new notebook.
# - Notebook cells: Create, delete, and move cells.
# - Toolbar: Learn about different buttons (save, add cell, run cell, stop, etc.).
# - Cell types: Switch between code and Markdown cells.
# - Running cells: Execute a cell (markdown suffices for now) and understand the output.
# - Saving notebooks: Save your work as `.ipynb` files.
#
#
#  Learn some keyboard shortcuts:
#
# -  `Shift+Enter`: Run the current cell.
#
# -  `Ctrl+Enter`: Run the cell and stay in the same cell.
#
# -  `A`: Insert a cell above the current cell.
#
# -  `B`: Insert a cell below the current cell.
#
# -  `C`: Copy the current cell.
#
# -  `V`: Paste the copied cell.
#
# -  `X`: Delete the current cell.
#
#
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3;color: grey;">
#
# ### 1
# Erkunden Sie die Jupyter-Schnittstelle:
#
# - Öffnen Sie ein neues Notebook.
# - Zellen im Notebook: Erstellen, Löschen und Verschieben von Zellen.
# - Symbolleiste: Lernen Sie die verschiedenen Schaltflächen kennen (Speichern, Zelle hinzufügen, Zelle ausführen, Stopp usw.).
# - Zelltypen: Wechseln Sie zwischen Code- und Markdown-Zellen.
# - Zellen ausführen: Führen Sie eine Zelle aus (Markdown reicht vorerst aus) und verstehen Sie die Ausgabe.
# - Speichern von Notizbüchern: Speichern Sie Ihre Arbeit als `.ipynb`-Dateien.
#
#
#  Lernen Sie einige Tastaturkürzel:
#
# - `Shift+Enter`: Die aktuelle Zelle ausführen.
#
# - `Strg+Enter`: Die Zelle ausführen und in der gleichen Zelle bleiben.
#
# - `A`: Eine Zelle oberhalb der aktuellen Zelle einfügen.
#
# - `B`: Eine Zelle unterhalb der aktuellen Zelle einfügen.
#
# - `C`: Kopieren der aktuellen Zelle.
#
# - `V`: Einfügen der kopierten Zelle.
#
# - `X`: Löschen der aktuellen Zelle.
#
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-light">
#
# <div style="display: flex; justify-content: space-between;">
#   <div style="width: 48%; line-height: 1.3;">
#
# ### 2
# Create a notebook structure using different heading levels:
#
# - Big Heading: Experimenting with Jupyter
# - Chapter: Introduction
# - Section: Section 1
# - Text: My name is...
# - Section: Section 2
# - Text: My expectations for this class are...
# - Chapter: Conclusion
#
# You can either write everything in a single cell or use a separate cell for each text block.
# Try both approaches.
#
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3;color: grey;">
#
# ### 2
# Erstellen Sie eine Notebookstruktur mit verschiedenen Überschriftenebenen:
#
# - Große Überschrift: Experimentieren mit Jupyter
# - Kapitel: Einführung
# - Abschnitt: Abschnitt 1
# - Text: Mein Name ist ...
# - Abschnitt: Abschnitt 2
# - Text: Meine Erwartungen an diese Klasse sind...
# - Kapitel: Schlussfolgerung
#
# Sie können entweder alles in eine einzige Zelle schreiben oder für jeden Textblock eine eigene Zelle verwenden.
# Versuchen Sie beide Ansätze.
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-light">
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.3;">
#
# ### 3
# Learn to create bullet and numbered lists in Markdown:
#
# - Bullet list: Use `-`, `+`, or `*`.
# - Numbered list: Just type the numbers (`1.`, `2.`, etc.).
#
#
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3;color: grey;">
#
# ### 3
# Lernen Sie, Aufzählungslisten und nummerierte Listen in Markdown zu erstellen:
#
# - Aufzählungsliste: Verwende `-`, `+` oder `*`.
# - Nummerierte Liste: Geben Sie einfach die Zahlen ein (`1.`, `2.`, etc.).
#
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-light">
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.3;">
#
# ### 4
# You can insert links and images using Markdown:
#
# - Link: `[Link text](http://example.com)`
# - Image: `![Alt text](http://example.com/image.jpg)`
#
#
# - Insert a link to the MaWi website.
# - Find the image address of the MaWi logo and embed it in your notebook.
#
#
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3;color: grey;">
#
# ### 4
# Mit Markdown können Sie Links und Bilder einfügen:
#
# - Link: `[Linktext](http://example.com)`
# - Bild: `![Alt-Text](http://example.com/image.jpg)`
#
#
# - Fügen Sie einen Link auf die MaWi-Website ein.
# - Suchen Sie die Bildadresse des MaWi-Logos und betten Sie es in Ihr Notebook ein.
#
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-light">
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.3;">
#
# ### 5
#
# - Understand the "Run All" feature, which allows you to run all the cells in a notebook at once.
# - Learn how to restart the kernel and re-run all cells to refresh the notebook.
#
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3;color: grey;">
#
# ### 5
#
# - Verstehen Sie die Funktion "Alle ausführen", mit der Sie alle Zellen in einem Notebook auf einmal ausführen können.
# - Lernen Sie, wie Sie den Kernel neu starten und alle Zellen erneut ausführen können, um das Notebook zu aktualisieren.
#
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-light">
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;">
#
# ### 6
#
# Tables are represented in Markdown with columns separated by the pipe character,
# `|` and rows on separate lines. A header row can be indicated by separating it from
# the table body with a row of at least three dashes in each cell, as in the following
# example:
#
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3;color: grey;">
#
# ### 6
#
# Tabellen werden in Markdown mit durch das Pipe-Zeichen getrennten Spalten dargestellt,
# `|` und Zeilen in separaten Zeilen. Eine Kopfzeile kann angezeigt werden, indem sie vom
# Tabellenkörper durch eine Reihe von mindestens drei Bindestrichen in jeder Zelle, wie im folgenden
# Beispiel:
#
# </div>
# </div>

# %% [raw]
# | Alloy | Melting point | Composition |
# | ----- | ------------- | ----------- |
# | Field's metal | 62 °C | Bi (32.5\%) / Sn (16.5\%) / In (51\%) |
# | Roses's metal | 98 °C | Bi (50\%) / Pb (25\%) / Sn (25\%) |
# | Wood's metal | 70 °C | Bi (50\%) / Pb (26.7\%) / Sn (13.3\%) / Cd (10\%) |
# | Cerrosafe | 74 °C | Bi (42.5\%) / Pb (37.7\%) / Sn (11.3\%) / Cd (8.5\%) |

# %% [markdown]
# | Alloy | Melting point | Composition |
# | ----- | ------------- | ----------- |
# | Field's metal | 62 °C | Bi (32.5\%) / Sn (16.5\%) / In (51\%) |
# | Roses's metal | 98 °C | Bi (50\%) / Pb (25\%) / Sn (25\%) |
# | Wood's metal | 70 °C | Bi (50\%) / Pb (26.7\%) / Sn (13.3\%) / Cd (10\%) |
# | Cerrosafe | 74 °C | Bi (42.5\%) / Pb (37.7\%) / Sn (11.3\%) / Cd (8.5\%) |

# %% [markdown]
# <div class="alert alert-block alert-light">
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.3;">
#          Create a table with the names, atomic numbers, and atomic masses of 5 elements from the periodic table.
#
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3;color: grey;">
#  Create a table with the names, atomic numbers, and atomic masses of 5 elements from the periodic table.
#
# </div>
# </div>

# %%
countdown_timer(20)

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/9/92/LaTeX_logo.svg/1599px-LaTeX_logo.svg.png?20210414121601" width=300px>
# </div>
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;">
#
# $\LaTeX$ is a high-quality typesetting system commonly used for creating documents that require complex formatting, such as academic papers, technical reports, and mathematical equations, due to its precise control over document layout and support for advanced typographic features.
#
# Like most of the tools we'll explore in this course, $\LaTeX$, too, has a Microsoft counterpart (Word). However, as with everything else we will encounter, the initially steeper learning curve will prove to be well worth the effort over time.
#
# In a Markdown cell, equations that are to appear inline with the text are delimited by single dollar signs `$`:
#
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.25;color: grey;">
#
# $\LaTeX$ ist ein hochwertiges Satzsystem, das aufgrund seiner präzisen Kontrolle über das Dokumentenlayout und der Unterstützung fortgeschrittener typografischer Funktionen häufig für die Erstellung von Dokumenten verwendet wird, die eine komplexe Formatierung erfordern, wie z. B. akademische Arbeiten, technische Berichte und mathematische Gleichungen.
#
# Wie die meisten Werkzeuge, die wir in diesem Kurs kennenlernen werden, hat auch $\LaTeX$ ein Microsoft-Gegenstück (Word). Doch wie bei allem anderen, was wir kennenlernen werden, wird sich die anfänglich steilere Lernkurve mit der Zeit als lohnend erweisen.
#
# In einer Markdown-Zelle werden Gleichungen, die inline mit dem Text erscheinen sollen, durch einfache Dollarzeichen `$` abgegrenzt:
# </div>
# </div>

# %% [raw]
# *A formula for the sum of the first $n$ positive integers*: $\sum_{i=1}^n i = \frac{n(n+1)}{2}$

# %% [markdown]
# *A formula for the sum of the first $n$ positive integers*: $\sum_{i=1}^n i = \frac{n(n+1)}{2}$

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;">
#
# "Displayed" equations that stand on their own are delimited by double dollar signs `$$`:
#
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.25;color: grey;">
#
# "Angezeigte" Gleichungen, die für sich alleine stehen, werden durch doppelte Dollarzeichen `$$` gekennzeichnet:
# </div>
# </div>

# %% [raw]
# *A formula for the sum of the first $n$ positive integers*:
# $$\sum_{i=1}^n i = \frac{n(n+1)}{2}$$

# %% [markdown]
# *A formula for the sum of the first $n$ positive integers*:
# $$\sum_{i=1}^n i = \frac{n(n+1)}{2}$$

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.3;">
#
# ## Quick Guide to Common $\LaTeX$ Commands for Equations
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3;color: grey;">
#
# ## Kurzanleitung für gängige $\LaTeX$-Befehle für Gleichungen
# </div>
# </div>
#
# |   Description                   |  Beschreibung                      |      Syntax                        |     Rendering                        |
# |------------------------------------------|------------------------------------------|--------------------------------------------|------------------------------------|
# | Superscript                              | Hochstellung                             | `$x^n, x^{nmk}$`                                | $ x^n, x^{nmk} $                            |
# | Subscript                                | Tiefstellung                             | `$x_i, x_{ijk}$`                                 | $ x_i, x_{ijk} $                            |
# | Superscript + Subscript          | Hochstellung + Tiefstellung                      | `$x_i^n$`                                 | $ x_i^n $                            |
# | Fractions                                | Brüche                                   | `$\frac{a}{b}$`                              | $ \frac{a}{b} $                    |
# | Square Root                              | Quadratwurzel                            | `$\sqrt{x}, \sqrt[n]{x}$`                  | $ \sqrt{x}, \sqrt[n]{x} $          |
# | Greek Letters                            | Griechische Buchstaben                   | `$\alpha, \beta, \gamma, \delta, \epsilon, \phi$`      | $ \alpha, \beta, \gamma, \delta, \epsilon, \phi $ |
# | Alternative Greek Letters                            | Alternative Griechische Buchstaben                   | `$\varepsilon, \varphi$`      | $\varepsilon, \varphi $ |
# | Plus-Minus Sign                          | Plus-Minus-Zeichen                       | `$\pm$`                                      | $ \pm $                            |
# | Multiplication Dot                       | Multiplikationspunkt                     | `$\cdot$`                                    | $ \cdot $                          |
# | Infinity                                 | Unendlichkeit                            | `$\infty$`                                   | $ \infty $                         |
# | Summation                                | Summenzeichen                            | `$\sum_{i=1}^{n}$`                           | $ \sum_{i=1}^{n} $                 |
# | Integral                                 | Integralzeichen                          | `$\int_{a}^{b}$`                             | $ \int_{a}^{b} $                   |
# | Trigonometric Functions | Trigonometrische Funktionen | `$\sin, \cos, \tan$`                          | $ \sin, \cos, \tan $               |
# | Logarithms and Exponentials              | Logarithmen und Exponentialfunktionen     | `$\log, \ln, \exp$`                            | $ \log, \ln, \exp $                |
# | Auto-sized Parentheses                   | Automatische Klammergrößen               | `$\left( \frac{a}{b} \right)$`               | $ \left( \frac{a}{b} \right) $     |
# | Auto-sized Brackets                      | Automatische eckige Klammern             | `$\left[ \frac{a}{b} \right]$`               | $ \left[ \frac{a}{b} \right] $     |
# | Auto-sized Curly Braces                  | Automatische geschweifte Klammern        | `$\left\{ \frac{a}{b} \right\}$`             | $ \left\{ \frac{a}{b} \right\} $   |
# | Equality, Less Than, Greater Than        | Gleichheit, kleiner als, größer als      | `$=, <, >$`                                  | $ =, <, > $                        |
# | Not Equal                                | Ungleich                                 | `$\neq$`                                     | $ \neq $                           |
# | Greater/Less Than or Equal To | Größer gleich, kleiner gleich          | `$\geq, \leq$`                               | $ \geq, \leq $                     |
# | Approximation                            | Annäherung                               | `$\approx$`                                  | $ \approx $                        |
# | Right/Left Arrow       | Pfeil rechts/links               | `$\rightarrow, \leftarrow$`                                  | $ \rightarrow, \leftarrow$                        |
# | Long Right/Left Arrow       | Langer Pfeil rechts/links               | `$\longrightarrow, \longleftarrow$`                                  | $ \longrightarrow, \longleftarrow$
# | Equilibrium Arrow       | Pfeil des Gleichgewichts               | `$\rightleftharpoons$` | $\rightleftharpoons$
# | Degree       | Grad               | `$^\circ$`                                  | $ ^\circ$

# %% [markdown]
# <div class="alert alert-block alert-light">
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.3;">
#
# ### Exercise
# Insert as many Markdown cells as needed and typeset the following equations using $\LaTeX$ syntax:
#
# - The Pythagorean theorem
# - Newton's second law
# - Einstein's mass-energy equivalence
# - The ideal gas law
# - The quadratic formula
# - The combustion of methane equation
#
# Try both the inline and the displayed equation formatting.
#
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3;color: grey;">
#
# ### Übung
# Fügen Sie so viele Markdown Zellen wie nötig ein und setzen Sie die folgenden Gleichungen mit der $\LaTeX$-Syntax:
#
# - Der Satz des Pythagoras
# - Newtons zweites Gesetz
# - Einstein's Masse-Energie-Äquivalenz
# - Das ideale Gasgesetz
# - Die quadratische Formel
# - Die Gleichung für die Verbrennung von Methan
#
# Probieren Sie sowohl die Inline- als auch die angezeigte Gleichungsformatierung aus.
#
#
# </div>
# </div>

# %% [markdown]
# <div style="text-align: center;">
# <img src="./figures/famous_equations_2.png" width="400">
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;">
#
# By default, $\LaTeX$ displays variables in italic in math mode, which is the standard for mathematical notation.
# Sometimes, however, you want to format text or symbols in upright roman font even within mathematical formulas, for example chemical formulas. The `\mathrm` command exists for this purpose and is used as follows:
#
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.5;color: grey;">
#
# Standardmäßig zeigt $\LaTeX$ im mathematischen Modus Variablen in kursiver Schrift an, was der Standard für mathematische Notation ist.
# Manchmal möchte man jedoch Text oder Symbole auch innerhalb mathematischer Formeln in aufrechter römischer Schrift formatieren, z. B. bei chemischen Formeln.
# Zu diesem Zweck gibt es den Befehl `\mathrm`, der wie folgt verwendet wird:
# </div>
# </div>
#
# ```latex
# \mathrm{A + B \longrightarrow C + D}
# ```

# %%
countdown_timer(20)

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://images.ctfassets.net/nrgyaltdicpt/2RrzN8eVNXo7w6kd7CBNrs/55d916a167fa65d94441cc215558182c/overleaf-logo-primary.jpg" width=400px>
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;">
#
# Let’s take it a step further. Now, we will learn how to create a complete document in $\LaTeX$, which can serve as a template for your future reports.
#
# 1. Go to https://sharelatex.tu-darmstadt.de and sign in using your TU credentials.
#
# 2. Click on `New Project` and choose a name, for example `Latex_exercise`.
#
# 3. Type the following code into your new document. This is the basic structure of a $\LaTeX$ document. *Try not to simply copy and paste, but type it yourself, at least the first time.*
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.5;color: grey;">
#
# Lassen Sie uns einen Schritt weiter gehen. Jetzt werden wir lernen, wie man ein komplettes Dokument in $\LaTeX$ erstellt, das als Vorlage für Ihre zukünftigen Berichte dienen kann.
#
# 1. Gehen Sie zu https://sharelatex.tu-darmstadt.de und melden Sie sich mit Ihren TU-Anmeldedaten an.
# 2. Klicken Sie auf `New Project` und wählen Sie einen Namen, zum Beispiel `Latex_exercise`.
# 3. Geben Sie den folgenden Code in Ihr neues Dokument ein. Dies ist die Grundstruktur eines $\LaTeX$-Dokuments. *Versuchen Sie, den Text nicht einfach zu kopieren und einzufügen, sondern ihn selbst zu schreiben, zumindest beim ersten Mal.*
# </div>
# </div>

# %% [markdown]
# ```latex
# % Comments are preceded by % signs
# \documentclass{report}              % Specify the document class (report format)
# \usepackage{graphicx}               % Required for inserting images
# \usepackage{amsmath}                % Required for inserting numbered equations
#
# \title{My First LaTeX Document}     % Title of the document
# \author{Your Name}                  % Your name
# \date{\today}                       % Date to be displayed
#
# \begin{document}                    % Start of the document
# \maketitle                          % Create the title section
#
# \chapter{Chapter title}             % Start a new chapter
# All work and no play makes Jack a dull boy. % Text content for the chapter
# All work and no play makes Jack a dull boy. % A new line with indentation is attained by inserting an empty line
#
# All work and no play makes Jack a dull boy.
#
# \section{Section title}             % Start a new section within the chapter
# \texttt{All work and no play makes Jack a dull boy.}       % Text with different styles
# \\                                                         % A new line without indentation is attained by typing \\
# \textbf{All work and no play makes Jack a dull boy.}       % Text with different styles
# \\
# \textit{All work and no play makes Jack a dull boy.}       % Text with different styles
#
# \subsection{Subsection title}       % Start a new subsection within the section
#
# \begin{itemize}                     % Start an itemized (bulleted) list
# \item All work and no play makes Jack a dull boy. % First bullet point
# \item All work and no play makes Jack a dull boy. % Second bullet point
# \end{itemize}                       % End of the itemized list
#
# \subsubsection{Subsubsection title}  % Start a new subsubsection
#
# \begin{enumerate}                   % Start an enumerated (numbered) list
# \item All work and no play makes Jack a dull boy. % First numbered point
# \item All work and no play makes Jack a dull boy. % Second numbered point
# \end{enumerate}                     % End of the enumerated list
#
# \paragraph{Paragraph title}         % Start a new paragraph
# Figure \ref{fig:my_fig} shows a scene from \emph{The Shining}. % Text content for the paragraph
#
# \begin{figure}[htbp]                                    % Let LaTeX decide where to place the figure
# \centering                                              % Center the figure
# \includegraphics[width=0.75\textwidth]{dummy_text.jpeg} % Include an image with specified width
# \caption{Yeah, you guessed it.}                         % Caption for the figure
# \label{fig:my_fig}                                      % Label for referencing the figure
# \end{figure}                                            % End of the figure environment
#
# Table \ref{tab:my_tab} shows more of the same.
#
# \begin{table}[htbp]                                 % Let LaTeX decide where to place the table
# \caption{Your Table Caption Here}                   % Caption for the table
# \label{tab:my_tab}                                  % Label for referencing the table
# \centering                                          % Center the table
# \begin{tabular}{cccccc}                             % Define the number of columns and their alignment
# \hline
# All work & and no play & makes Jack & a dull boy \\     % Row 1 of the table
# \hline
# \hline                                              % Add a double line for separation
# All work & and no play & makes Jack & a dull boy \\     % Row 2 of the table
# All work & and no play & makes Jack & a dull boy \\     % Row 3 of the table
# \hline                                              % End of the table
# \end{tabular}
# \end{table}
#
# As shown in Equation \eqref{eq:reaction}, the reaction proceeds from A and B to C and D.
#
# \begin{equation}
# \mathrm{A + B \longrightarrow C + D}
# \label{eq:reaction}
# \end{equation}
#
# \end{document}
# ```

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;">
#
# 4. Click on `Compile` to see the typeset document.
# 5. Experiment with the commands:
#
#     - See how different font formatting works.
#
#     - Remove the placeholder text and replace it with your own content (it can be anything you like). If you're running low on ideas, feel free to visit the Wikipedia page for one of the equations you typeset earlier and copy some text, images, and equations from there.
#
#     - Understand how different elements (bullet lists, figures, tables) are made.
#
#         - What do `&` and `\\` in a table do?
#
#     - Fill the table with your chosen numbers or data.
#
#     - Find an image, save it in the same folder as your document, and replace the placeholder image with your chosen one.
#
#     - Insert one of the equations you have typeset earlier.
#
# </div>
#
# <div style="width: 4%;">
# </div>
#
# <div style="width: 48%; line-height: 1.5;color: grey;">
#
# 4. Klicken Sie auf `Compile`, um das gesetzte Dokument zu sehen.
# 5. Experimentieren Sie mit den Befehlen:
#
#     - Sehen Sie sich an, wie unterschiedliche Schriftformatierungen funktionieren.
#
#     - Entfernen Sie den Platzhaltertext und ersetzen Sie ihn durch Ihren eigenen Inhalt (das kann alles sein, was Sie wollen). Wenn Ihnen die Ideen ausgehen, können Sie die Wikipedia-Seite für eine der Gleichungen, die Sie zuvor getippt haben, besuchen und einige Texte, Bilder und Gleichungen von dort kopieren.
#
#     - Verstehen, wie die verschiedenen Elemente (Aufzählungen, Abbildungen, Tabellen) erstellt werden.
#
#         - Was bewirken `&` und `\` in einer Tabelle?
#
#     - Füllen Sie die Tabelle mit den von Ihnen gewählten Zahlen oder Daten.
#
#     - Suchen Sie ein Bild, speichern Sie es in demselben Ordner wie Ihr Dokument und ersetzen Sie das Platzhalterbild durch das von Ihnen gewählte Bild.
#
#     - Fügen Sie eine der Gleichungen ein, die Sie zuvor geschrieben haben.
#
# </div>
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;">
#
# 6. At any time, click the `Compile` button to view the formatted document.
#
# 7. Find the `Share` button in the top-right corner and invite fellow students. Once the invitation is accepted, you can all collaborate on the same document in real time, eliminating the need to send changes back and forth. This is especially useful for your lab reports!
#
# 8. When you're ready, click the download icon next to the `Compile` button.
#
# 9. When you are satisfied with your document, upload it to Moodle.
#
# </div>
#
# <div style="width: 4%;">
# </div>
#
# <div style="width: 48%; line-height: 1.5;color: grey;">
#
# 6. Klicken Sie jederzeit auf die Schaltfläche `Compile`, um das formatierte Dokument zu sehen.
#
# 7. Suchen Sie die Schaltfläche `Share` in der oberen rechten Ecke und laden Sie andere Studierende ein. Sobald die Einladung angenommen wurde, können Sie alle gemeinsam in Echtzeit an demselben Dokument arbeiten, ohne dass Sie Änderungen hin- und herschicken müssen. Dies ist besonders nützlich für Ihre Laborberichte!
#
# 8. Wenn Sie bereit sind, klicken Sie auf das Download-Symbol neben der Schaltfläche `Compile`.
#
# 9. Wenn Sie mit Ihrem Dokument zufrieden sind, laden Sie es in Moodle hoch.
#
# </div>
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;">
#
# Congratulations! You have just written your first $\LaTeX$ document. There are numerous customizations you can apply, and TU Darmstadt even offers a [repository of templates](https://www.ulb.tu-darmstadt.de/finden_nutzen/medien_nutzen/dokumente_erstellen/latex/index.de.jsp) for your reports. This simple exercise was designed to ease your transition into using $\LaTeX$. While it may feel unfamiliar at first, you will appreciate its robustness for handling complex documents.
#
# This page will guide you through this new experience: https://de.overleaf.com/learn/latex/Learn_LaTeX_in_30_minutes
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.5;color: grey;">
#
# Herzlichen Glückwunsch! Sie haben gerade Ihr erstes $\LaTeX$-Dokument geschrieben. Es gibt zahlreiche Anpassungen, die Sie vornehmen können, und die TU Darmstadt bietet sogar eine [Sammlung von Vorlagen](https://www.ulb.tu-darmstadt.de/finden_nutzen/medien_nutzen/dokumente_erstellen/latex/index.de.jsp) für Ihre Berichte an. Diese einfache Übung soll Ihnen den Einstieg in die Benutzung von $\LaTeX$ erleichtern. Auch wenn es sich anfangs ungewohnt anfühlen mag, werden Sie seine Robustheit bei der Bearbeitung komplexer Dokumente zu schätzen wissen.
#
# Diese Seite wird Sie durch diese neue Erfahrung führen: https://de.overleaf.com/learn/latex/Learn_LaTeX_in_30_minutes
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.3;">
#
# ### Reminder
# Don't forget to save a backup of this notebook to your device, just in case something goes wrong with the hub.
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.3; color: grey;">
#
# ### Erinnerung
# Vergessen Sie nicht, eine Sicherungskopie dieses Notizbuchs auf Ihrem Gerät zu speichern, für den Fall, dass etwas mit dem Hub schief geht.
# </div>
# </div>
