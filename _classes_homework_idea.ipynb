# %% [markdown]
# <div class="alert alert-danger" role="alert">
#
# <div style="display: flex; justify-content: space-between; font-size: 12px;">
# <div style="width: 48%; line-height: 1.25;">
#
# ### Until February 7: Course Evaluation
#
# We invite you to take part in the evaluation of this course.
# Simply scan the QR code below or visit the [link](https://evaluation.tu-darmstadt.de/evasys/online.php?pswd=ZZ95U) to access the evaluation form.
#
# If you enjoy the course:<br> Let us know what’s working well. Your positive feedback helps us understand which aspects are effective and should be retained in future courses.
#
# If you have suggestions or criticism:<br> This is your chance to highlight areas for improvement. Constructive feedback helps us tailor the course to better meet your needs.
#
# *Speak to Us Directly*:<br>
# If you are unsatisfied with any aspect of the course, we encourage you to speak to us directly. We still have time to make adjustments, and we can address your concerns faster than the central processing of the evaluation results. Your input matters, and we’re here to help you.
#
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.25; color: grey;">
#
# ### Bis zum 7. Februar: Lehrveranstaltungsevaluation
#
# Wir laden Sie ein, sich an der Bewertung dieses Kurses zu beteiligen.
# Scannen Sie einfach den nachstehenden QR-Code oder besuchen Sie den [Link](https://evaluation.tu-darmstadt.de/evasys/online.php?pswd=ZZ95U), um das Bewertungsformular aufzurufen.
#
# Wenn Ihnen der Kurs gefällt:<br> Lassen Sie uns wissen, was gut funktioniert. Ihr positives Feedback hilft uns zu verstehen, welche Aspekte effektiv sind und in zukünftigen Kursen beibehalten werden sollten.
#
# Wenn Sie Vorschläge oder Kritik haben:<br> Hier haben Sie die Möglichkeit, auf verbesserungswürdige Bereiche hinzuweisen. Konstruktives Feedback hilft uns, den Kurs besser auf Ihre Bedürfnisse abzustimmen.
#
# *Sprechen Sie uns direkt an*:<br>
# Wenn Sie mit irgendeinem Aspekt des Kurses unzufrieden sind, empfehlen wir Ihnen, direkt mit uns zu sprechen. Wir haben noch Zeit, Anpassungen vorzunehmen, und wir können uns schneller um Ihre Anliegen kümmern als die zentrale Verarbeitung der Bewertungsergebnisse. Ihre Meinung ist uns wichtig, und wir sind hier, um Ihnen zu helfen.
#
# </div>
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="./evaluation_qr.png" style="width: 150px;">
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Python_logo_and_wordmark.svg/972px-Python_logo_and_wordmark.svg.png?20210516005643" alt="The Python logo" style="width: 60%; max-width: 500px;">
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;">
#
# ### Instructions
#
# - Enter your matriculation number in the first cell at the line `student_id =` and then execute the cell.
#
# - Modify this notebook directly.
#
# - <span style="color:red;"> Do not clear the outputs of your cells!</span>
#
# - Comments are essential to clarify your thought process, as we cannot interpret your intentions or debug your code.
# Subtasks without comments will incur a penalty of 0.5 points per subtask.
#
# - Once completed, upload your notebook to the weekly assignment.
#
# - There are 14 points available in total: you need at least 10 points to pass.
#
# </div>
# <div style="width: 4%;">
# </div>
# <div style="width: 48%; line-height: 1.35; color: grey;">
#
# ### Anweisungen
#
# - Geben Sie Ihre Matrikelnummer in die erste Zelle der Zeile `student_id =` ein und führen Sie dann die Zelle aus.
#
# - Ändern Sie dieses Notizbuch direkt.
#
# - <span style="color:red;"> Löschen Sie nicht die Ausgaben Ihrer Zellen!</span>
#
# - Kommentare sind unerlässlich, um Ihren Gedankengang zu verdeutlichen, da wir Ihre Absichten nicht interpretieren oder Ihren Code debuggen können.
# Teilaufgaben ohne Kommentare führen zu einem Abzug von 0.5 Punkten pro Teilaufgabe.
#
# - Wenn Sie fertig sind, laden Sie Ihr Notizbuch in die wöchentliche Aufgabe hoch.
#
# - Es gibt insgesamt 14 Punkte: Sie brauchen mindestens 10 Punkte, um zu bestehen.
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;">
#
# Ensure that your notebook runs from top to bottom. You can verify this by clicking the "Restart" button and then "Run All." If your notebook fails to execute properly, the corresponding task will incur a penalty.
#
# </div>
# <div style="width: 48%; line-height: 1.5; color: grey;">
#
# Stellen Sie sicher, dass Ihr Notebook von oben nach unten läuft. Sie können dies überprüfen, indem Sie auf die Schaltfläche "Restart" und dann auf "Run All" klicken. Wenn Ihr Notebook nicht ordnungsgemäß ausgeführt wird, wird die entsprechende Aufgabe mit einer Strafe belegt.
#
# </div>
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;">
#
# This week's exercise is inspired by the following video tutorial:
#
# </div>
# <div style="width: 48%; line-height: 1.5; color: grey;">
#
# Die Übung dieser Woche wurde durch das folgende Videotutorial inspiriert:
#
# </div>
# </div>
#
# <div style="text-align: center;">
#
# [![Watch the tutorial](https://img.youtube.com/vi/cM_ocyOrs_k/0.jpg)](https://www.youtube.com/watch?v=cM_ocyOrs_k)
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-light">
#
# #### 1 (1.5 P)
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;<div style="width: 48%; line-height: 1.5;">
#
# 1. (0.5 P) Define a class named Weapon: The class should represent different types of weapons that characters can use in the game.
# 2. (0.5 P) Implement an __init__ method (this concept is generally called constructor) with four parameters:
#     - `name` (str): The name of the weapon.
#     - `weapon_type` (str): The type of weapon.
#     - `damage` (int): The amount of damage the weapon deals.
#     - `value` (int): The in-game value or cost of the weapon.
# 3. (0.25 P) Assign these parameters to instance attributes in the constructor: Use `self.name`, `self.type`, `self.damage`, and `self.value` to store the values in the object.
# 4. (0.25 P) Type hinting is required: Ensure that each parameter has an appropriate type hint to indicate expected data types.
#
# </div>
# <div style="width: 48%; line-height: 1.5;<div style="width: 48%; line-height: 1.5;color: grey;">
#
# 1. (0.5 P) Definieren Sie eine Klasse names 'Weapon': Die Klasse sollte verschiedene Arten von Waffen die Charaktere im Spiel nutzen können repräsentieren.
# 2. (0.5 P) Implementieren Sie eine __init__ Methode (dieses Konzept wird allgemein als 'constructor' bezeichnet) mit vier Parametern:
#     - `name` (str): Name der Waffe.
#     - `weapon_type` (str): Art der Waffe.
#     - `damage` (int): Die Menge an Schaden den die Waffe verursacht.
#     - `value`: Der in-game Wert, bzw. Kosten der Waffe.
# 3. (0.25 P) Weisen Sie diese Parameter im constructor Instanz Attributen zu: Benutzen Sie `self.name`, `self.type`, `self.damage` und `self.value` um die Werte im Objekt zu speichern.
# 4. (0.25 P) Nutzen Sie Type hinting: Stellen Sie sicher das jeder Parameter einen angemessenen type hint aufweist um den erwarteten Datentyp anzugeben.
#
# </div>
# </div>
#
# Type hints use the following syntax:
# ```python
# def function_with_type_hint(int_argument: int, str_argument: str, float_argument: float) -> None:
#     pass
# ```

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://apps.joltteam.com/cdn/brikbuild/link-sword-zelda-pixel-art-8bit-brik-bin-link-nes-nintendo-pixel-art-popular-designs-popular-games-sword-zelda-5a24f9b2f6c96a8d297207f4.brickImg.jpg" style="width: 200px;">
# </div>

# %%
#### 1. Creating the `Weapon` Class

# Define the Weapon class
class Weapon:
    """
    A blueprint for weapons in the game. Weapons have a name, type, damage, and value.
    """
    def __init__(self, name: str, weapon_type: str, damage: int, value: int):
        self.name = name
        self.type = weapon_type
        self.damage = damage
        self.value = value

# %% [markdown]
# <div class="alert alert-block alert-light">
#
# #### 2 (1.5 P)
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;<div style="width: 48%; line-height: 1.5;">
#
# 1. (0.5 P) Create three `Weapon` objects with specific attributes. The following weapons must be created using the `Weapon` class:
#
# - `fists`
#   - Name: `"Fists"`
#   - Type: `"Melee"`
#   - Damage: `5`
#   - Value: `0`
#
# - `sword`
#   - Name: `"Sword"`
#   - Type: `"Melee"`
#   - Damage: `15`
#   - Value: `10`
#
# - `bow`
#   - Name: `"Bow"`
#   - Type: `"Ranged"`
#   - Damage: `12`
#   - Value: `8`
#
# 2. (0.5 P) Ensure the objects are correctly initialized: Store each weapon in a variable (`fists`, `sword`, `bow`) and pass the appropriate arguments to the `Weapon` constructor.
#
# 3. (0.5 P) Print a specific attributes from one of the weapon objects: Use the `print()` function to output the name and damage of the `sword` object.
#
#
# </div>
# <div style="width: 48%; line-height: 1.5;<div style="width: 48%; line-height: 1.5;color: grey;">
#
# 1. (0.5 P) Erstellen Sie drei `Weapon` Objekte mit spezifischen Attributen. Die folgenden Waffen müssen mithilfe der `Weapon` Klasse erstellt werden:
# - `fists`
#   - Name: `"Fists"`
#   - Type: `"Melee"`
#   - Damage: `5`
#   - Value: `0`
#
# - `sword`
#   - Name: `"Sword"`
#   - Type: `"Melee"`
#   - Damage: `15`
#   - Value: `10`
#
# - `bow`
#   - Name: `"Bow"`
#   - Type: `"Ranged"`
#   - Damage: `12`
#   - Value: `8`
#
# 2. (0.5 P) Stellen Sie sicher das die Objekt korrekt initialisiert sind: Weisen sie jede Waffe einer Variablen zu (`fists`, `sword`, `bow`) und übergeben Sie die passenden Argumente an den `Weapon` constructor.
#
# 3. (0.5 P) Geben Sie spezifische Attribute von einem der Waffenobjekte aus: Nutzen Sie `print()` um den Namen und Schaden von `sword` auszugeben.
#
# </div>
# </div>

# %%
#### 2. Creating and Testing Weapons

# Create three weapons
fists = Weapon(name="Fists", weapon_type="Melee", damage=5, value=0)
sword = Weapon(name="Sword", weapon_type="Melee", damage=15, value=10)
bow = Weapon(name="Bow", weapon_type="Ranged", damage=12, value=8)

# Print weapon details
print(f"Weapon: {sword.name}, Damage: {sword.damage}")

# %% [markdown]
# <div class="alert alert-block alert-light">
#
# #### 3 (1.5 P)
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;<div style="width: 48%; line-height: 1.5;">
#
# 1. (0.5 P) Define a class named `Character`: This class will serve as a blueprint for game characters.
#
# 2. (0.25 P) Implement an `__init__` method with two parameters:
#    - `name` (str): The name of the character.
#    - `health` (int): The starting health of the character.
#
# 3. (0.25 P) Define the following instance attributes:
#    - `self.name`: Stores the character's name.
#    - `self.health`: Stores the current health of the character.
#    - `self.weapon`: Initializes as `None`, meaning the character starts without a weapon.
#
# 4. (0.5 P) Implement an `attack` method that allows one character to attack another.
#    - The method should take one parameter:
#      - `target` (Character): The character being attacked.
#    - If the attacker has a weapon:
#      - The target's health is reduced by the attacker's weapon damage.
#      - Print a message in the format:
#        ```python
#        "{attacker} attacks {target} with {weapon} for {damage} damage!"
#        ```
#    - If the attacker has no weapon:
#      - Print a message stating that they cannot attack.
#    - Ensure the target’s health never drops below zero using the `max()` function.
#    - If the target's health reaches zero, print a message stating that the target has been defeated.
#
# </div>
# <div style="width: 48%; line-height: 1.5;<div style="width: 48%; line-height: 1.5;color: grey;">
#
# 1. (0.5 P) Definieren Sie eine Klasse namens `Character`: Diese Klasse wird als Blaupause für Spielcharaktere dienen.
#
# 2. (0.25 P) Implementieren Sie eine `__init__` Methode mit zwei Parametern:
#   -`name` (str): Der Name des Charakters.
#   - `health` (int): Die anfängliche Gesundheit des Charakters.
#
# 3. (0.25 P) Definieren Sie die folgenden Instanzattribute:
#   - `self.name`: Speichert den Namen des Charakters.
#   - `self.health`: Speichert die aktuelle Gesundheit des Charakters
#   - `self.weapon`: Initialisiert als `None`, der Charakter startet ohne Waffe
#
#
# 4. (0.5 P) Implementieren Sie eine `attack` Methode die es einem Charakter erlaubt einen anderen anzugreifen.
#   - Die Methode sollte einen Parameter akzeptieren:
#     -`target` (Character): Der attackierte Charakter
#   - Wenn der Angreifer eine Waffe hat:
#     - Die Gesundheit des Ziels wird um den Schaden der Waffe des Angreifers reduziert
#     - Geben Sie eine Nachricht der Form
#         ```python
#        "{attacker} greift {target} mit {weapon} an und verursacht {damage} Schaden!"
#        ```
#   - Wenn der Angreifer keine Waffe hat:
#     - Geben Sie eine Nachricht aus, die besagt das der Charakter nicht angreifen kann.
#   - Stellen Sie mit der `max()` Funktion sicher das die Gesundheit des Ziels nie unter null fällt.
#   - Wenn die Gesundheit des Ziels null erreicht geben Sie eine Nachricht aus das das Ziel besiegt wurde.
#
# </div>
# </div>

# %%
#### 3. Creating the `Character` Class


# Define the Character class
class Character:
    """
    A blueprint for characters in the game. Characters have a name, health, and a weapon.
    They can attack other characters, and their attributes can be customized.
    """
    def __init__(self, name: str, health: int):
        self.name = name
        self.health = health
        self.weapon = None  # Each character starts without a weapon

    def attack(self, target):
        """
        Attack another character using the damage of the weapon.
        If the character has no weapon, it deals 0 damage.
        """
        if self.weapon:
            damage = self.weapon.damage
            target.health = max(0, target.health - damage)
            print(f"{self.name} attacks {target.name} with {self.weapon.name} for {damage} damage!")
        else:
            print(f"{self.name} tries to attack, but they have no weapon!")
        
        if target.health == 0:
            print(f"{target.name} has been defeated!")

# %% [markdown]
# <div class="alert alert-block alert-light">
#
# #### 4 (1.5 P)
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;<div style="width: 48%; line-height: 1.5;">
#
# 1. (0.5 P) Create two `Character` objects with the following attributes:
#    - `hero`:
#      - `name`: "Hero"
#      - `health`: 100
#    - `enemy`:
#      - `name`: "Goblin"
#      - `health`: 50
#
# 2. (0.5 P) Equip each character with a weapon by assigning a `Weapon` object to their `weapon` attribute:
#    - Equip the `hero` with the `sword` weapon.
#    - Equip the `enemy` with the `fists` weapon.
#
# 3. (0.25 P) Simulate a battle by calling the `attack` method:
#    - The `hero` attacks the `enemy`.
#    - The `enemy` attacks the `hero`.
#
# 4. (0.25 P) Print the remaining health of both characters using formatted strings:
#    - Format for hero:
#      ```python
#      print(f"{hero.name} Health: {hero.health}")
#      ```
#    - Format for enemy:
#      ```python
#      print(f"{enemy.name} Health: {enemy.health}")
#      ```
#
# </div>
# <div style="width: 48%; line-height: 1.5;<div style="width: 48%; line-height: 1.5;color: grey;">
#
# 1. (0.5 P) Erstellen sie zwei Charaktere mit den folgenden Attributen:
#    - `hero`:
#      - `name`: "Hero"
#      - `health`: 100
#    - `enemy`:
#      - `name`: "Goblin"
#      - `health`: 50
#
# 2. (0.5 P) Rüsten Sie jeden Charakter mit eine Waffe aus, indem sie seinem `weapon` Attribut eine Waffe zuweisen:
#    - Rüsten sie `hero` mit `sword` aus.
#    - Rüsten sie `enemy` mit `fists` aus.
#
# 3. (0.25 P) Simulieren Sie einen Kampf indem sie die `attack` Methode aufrufen:
#   - `hero` greift `enemy` an
#   - `enemy` greift `hero` an
#
# 4. (0.25 P) Geben Sie die verbleibende Gesundheit beider Charaktere formatiert aus:
#
#    - Format für hero:
#      ```python
#      print(f"{hero.name} Gesundheit: {hero.health}")
#      ```
#    - Format für enemy:
#      ```python
#      print(f"{enemy.name} Gesundheit: {enemy.health}")
#      ```
# </div>
# </div>

# %%
#### 4. Testing the `Character` Class

# Create two characters: a hero and an enemy
hero = Character(name="Hero", health=100)
enemy = Character(name="Goblin", health=50)

# Equip weapons
hero.weapon = sword
enemy.weapon = fists

# Simulate attacks
hero.attack(enemy)  # Hero attacks Goblin
enemy.attack(hero)  # Goblin attacks Hero

# Check health
print(f"{hero.name} Health: {hero.health}")
print(f"{enemy.name} Health: {enemy.health}")

# %% [markdown]
# <div class="alert alert-block alert-light">
#
# #### 5 (2.5 P)
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;<div style="width: 48%; line-height: 1.5;">
#
# 1. (1 P) Define a `Hero` subclass that inherits from `Character`.
#    - Use `class Hero(Character):` to indicate inheritance.
#    - Implement an `__init__` method that takes:
#      - `name` (str): The name of the hero.
#      - `health` (int): The hero’s starting health.
#    - Call the parent class’s constructor using `super().__init__(name, health)`.
#    - Set the following attributes:
#      - `default_weapon`: Assign the `fists` weapon as the default.
#      - `weapon`: Initialize the hero’s weapon as the default weapon.
#
# 2. (1 P) Implement two methods in the `Hero` subclass:
#    - `equip(self, weapon: Weapon)`:
#      - Assign a new weapon to the hero.
#      - Print a message in the format:
#        ```python
#        print(f"{self.name} equipped {self.weapon.name}!")
#        ```
#    - `drop_weapon(self)`:
#      - Reset the hero’s weapon to the default weapon.
#      - Print a message in the format:
#        ```python
#        print(f"{self.name} dropped their weapon and now uses {self.weapon.name}.")
#        ```
#
# 3. (0.5 P) Define an `Enemy` subclass that inherits from `Character`.
#    - Use `class Enemy(Character):` to indicate inheritance.
#    - Implement an `__init__` method that takes:
#      - `name` (str): The name of the enemy.
#      - `health` (int): The enemy’s starting health.
#      - `weapon` (Weapon): The weapon assigned to the enemy at creation.
#    - Call the parent class’s constructor using `super().__init__(name, health)`.
#    - Assign the `weapon` parameter to `self.weapon`, ensuring that enemies always start with a predefined weapon.
#
# </div>
# <div style="width: 48%; line-height: 1.5;<div style="width: 48%; line-height: 1.5;color: grey;">
#
#
#
# </div>
# </div>

# %%
#### 5. Implementing Class Inheritance

# Define the Hero subclass
class Hero(Character):
    """
    A specialized character class for heroes. Heroes can equip and drop weapons.
    """
    def __init__(self, name: str, health: int):
        super().__init__(name, health)
        self.default_weapon = fists
        self.weapon = self.default_weapon

    def equip(self, weapon: Weapon):
        """
        Equip a new weapon.
        """
        self.weapon = weapon
        print(f"{self.name} equipped {self.weapon.name}!")

    def drop_weapon(self):
        """
        Drop the current weapon and revert to the default weapon.
        """
        self.weapon = self.default_weapon
        print(f"{self.name} dropped their weapon and now uses {self.weapon.name}.")

# Define the Enemy subclass
class Enemy(Character):
    """
    A specialized character class for enemies. Enemies always start with a specified weapon.
    """
    def __init__(self, name: str, health: int, weapon: Weapon):
        super().__init__(name, health)
        self.weapon = weapon

# %% [markdown]
# <div class="alert alert-block alert-light">
#
# #### 6 (2 P)
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;<div style="width: 48%; line-height: 1.5;">
#
# 1. (0.5 P) Create a `Hero` and an `Enemy` object
#    - Instantiate a `Hero` object with:
#      - `name`: `"Knight"`
#      - `health`: `120`
#    - Instantiate an `Enemy` object with:
#      - `name`: `"Orc"`
#      - `health`: `80`
#      - `weapon`: `bow`
#
# 2. (0.5 P) Simulate a battle
#    - Equip the hero with a `sword`.
#    - The hero attacks the enemy.
#    - The enemy attacks the hero.
#
# 3. (0.5 P) Test the hero's ability to drop a weapon
#    - The hero drops their weapon.
#    - The hero attacks the enemy again (this time using fists, since the weapon has been reset to the default).
#
# 4. (0.5 P) Verify the output
#    - Ensure messages are printed confirming:
#      - The hero equipping a weapon.
#      - The attacks and the damage dealt.
#      - The hero dropping their weapon and switching to fists.
#
#
# </div>
# <div style="width: 48%; line-height: 1.5;<div style="width: 48%; line-height: 1.5;color: grey;">
#
#
#
# </div>
# </div>

# %%
#### 6. Testing Hero and Enemy Subclasses

# Create a hero and an enemy
hero = Hero(name="Knight", health=120)
enemy = Enemy(name="Orc", health=80, weapon=bow)

# Simulate a battle
hero.equip(sword)
hero.attack(enemy)
enemy.attack(hero)

# Hero drops their weapon
hero.drop_weapon()
hero.attack(enemy)  # Attacks with fists

# %% [markdown]
# <div class="alert alert-block alert-light">
#
# #### 7 (3.5 P)
#
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%; line-height: 1.5;<div style="width: 48%; line-height: 1.5;">
#
#
# 1. (0.5 P) Define a function `battle(hero: Character, enemy: Character)`.
#    - This function should accept two arguments:
#      - `hero`: an instance of the `Hero` class.
#      - `enemy`: an instance of the `Enemy` class.
#    - The function should manage the combat flow and print the results of each turn.
#
# 2. (0.5 P) At the start of the battle:
#    - Print a message announcing the battle:
#      ```python
#      print(f"Battle begins: {hero.name} vs {enemy.name}!")
#      ```
#    - Print the initial health of both characters:
#      ```python
#      print(f"{hero.name} (HP: {hero.health}) vs {enemy.name} (HP: {enemy.health})")
#      ```
#
# 3. (1 P) Implement a turn-based combat loop:
#    - Continue the battle *while both characters* have health greater than zero.
#    - Track turn numbers and print:
#      ```python
#      print(f"--- Turn {turn} ---")
#      ```
#
# 4. (1 P) Within each turn:
#    - The hero attacks first by calling `hero.attack(enemy)`.
#      - If the enemy's health reaches zero, print a victory message and exit the loop:
#        ```python
#        print(f"{enemy.name} has been defeated! {hero.name} wins!")
#        ```
#    - The enemy attacks second by calling `enemy.attack(hero)`.
#      - If the hero's health reaches zero, print a defeat message and exit the loop:
#        ```python
#        print(f"{hero.name} has been defeated! {enemy.name} wins!")
#        ```
#    - Display the remaining health of both characters at the end of the turn.
#
# 5.  (0.5 P)After the loop exits, print a final message:
#    ```python
#    print("The battle is over.")
#    ```
#
# </div>
# <div style="width: 48%; line-height: 1.5;<div style="width: 48%; line-height: 1.5;color: grey;">
#
#
#
# </div>
# </div>

# %%
# Simulate a battle loop between the hero and the enemy
def battle(hero: Character, enemy: Character):
    """
    Simulates a turn-based battle between a hero and an enemy.
    The loop continues until one of them is defeated.
    """
    print(f"Battle begins: {hero.name} vs {enemy.name}!")
    print(f"{hero.name} (HP: {hero.health}) vs {enemy.name} (HP: {enemy.health})\n")

    turn = 1  # Keeps track of the turn number

    while hero.health > 0 and enemy.health > 0:
        print(f"--- Turn {turn} ---")
        
        # Hero attacks the enemy
        hero.attack(enemy)
        if enemy.health == 0:
            print(f"{enemy.name} has been defeated! {hero.name} wins!\n")
            break
        
        # Enemy attacks the hero
        enemy.attack(hero)
        if hero.health == 0:
            print(f"{hero.name} has been defeated! {enemy.name} wins!\n")
            break
        
        # Print the health status
        print(f"{hero.name} (HP: {hero.health}) vs {enemy.name} (HP: {enemy.health})\n")
        
        # Increment the turn
        turn += 1
    
    print("The battle is over.")

# Create a hero and an enemy
hero = Hero(name="Knight", health=120)
enemy = Enemy(name="Orc", health=80, weapon=bow)

# Equip the hero with a weapon
hero.equip(sword)

# Start the battle
battle(hero, enemy)

# %% [markdown]
# ---
# ---
#
# # Feedback from instructor

# %%
# Adjust task points and feedback
tasks = [
    {"task": 1, "points": 1.5, "feedback": ""},
    {"task": 2, "points": 1.5, "feedback": ""},
    {"task": 3, "points": 1.5, "feedback": ""},
    {"task": 4, "points": 1.5, "feedback": ""},
    {"task": 5, "points": 2.5, "feedback": ""},
    {"task": 6, "points": 2, "feedback": ""},
    {"task": 7, "points": 3.5, "feedback": ""}
]

# Print task details
for task in tasks:
    print(f"Task {task['task']:>2} | Points: {task['points']:<2} | {task['feedback']}\n")

# Calculate and print total points
total_points = sum(task['points'] for task in tasks)
print(f"Total Points: {total_points}")
